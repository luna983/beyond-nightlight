# %%
import pandas as pd
import shapely
import shapely.geometry
import geopandas as gpd
from maskrcnn.preprocess.sample_aoi import aoi_to_chip

# define paths
SVY_IN_DIR = 'data/GiveDirectly/Survey/GE_Luna_Extract_2018-09-19.dta'
OUT_IMG_DIR = 'data/Experiment1/aoi.csv'


# specify tiles to be pulled
LON_TILE_SHIFT = [0]
LAT_TILE_SHIFT = [0]

df = pd.read_stata(SVY_IN_DIR)
df = df.dropna(subset=['s19_gps_latitude', 's19_gps_longitude'])

# %%
df.rename(
    {'s19_gps_latitude': 'lat', 's19_gps_longitude': 'lon'},
    axis=1, inplace=True)

# %%
# save chip level data
df = aoi_to_chip(df=df, indices=['s1_hhid_key'],
                 file_name='{}_{}',
                 lon_tile_shift=LON_TILE_SHIFT,
                 lat_tile_shift=LAT_TILE_SHIFT,
                 indices_type=str)
df.to_csv(OUT_IMG_DIR)

# %%
df
# Out:
#                          s1_hhid_key        lon       lat  lon_tile_width  \
# index
# 601010101002-002_0  601010101002-002  34.244534  0.137276        0.001717
# 601010101002-031_0  601010101002-031  34.245098  0.134500        0.001717
# 601010101002-041_0  601010101002-041  34.239479  0.137575        0.001717
# 601010101002-054_0  601010101002-054  34.248672  0.135761        0.001717
# 601010101002-060_0  601010101002-060  34.750008 -0.078272        0.001717
# ...                              ...        ...       ...             ...
# 601050504009-051_0  601050504009-051  34.319874  0.181975        0.001717
# 601050504009-070_0  601050504009-070  34.315914  0.170659        0.001717
# 601050504009-098_0  601050504009-098  34.325333  0.183717        0.001717
# 601050504009-143_0  601050504009-143  34.317154  0.170694        0.001717
# 601050504009-156_0  601050504009-156  34.316101  0.170643        0.001717
#
#                     lat_tile_width  chip    lon_min    lon_max   lat_min  \
# index
# 601010101002-002_0        0.001717     0  34.243675  34.245392  0.136418
# 601010101002-031_0        0.001717     0  34.244240  34.245956  0.133642
# 601010101002-041_0        0.001717     0  34.238621  34.240337  0.136717
# 601010101002-054_0        0.001717     0  34.247814  34.249531  0.134903
# 601010101002-060_0        0.001717     0  34.749149  34.750866 -0.079130
# ...                            ...   ...        ...        ...       ...
# 601050504009-051_0        0.001717     0  34.319016  34.320732  0.181117
# 601050504009-070_0        0.001717     0  34.315056  34.316772  0.169800
# 601050504009-098_0        0.001717     0  34.324474  34.326191  0.182858
# 601050504009-143_0        0.001717     0  34.316296  34.318012  0.169836
# 601050504009-156_0        0.001717     0  34.315243  34.316959  0.169784
#
#                      lat_max
# index
# 601010101002-002_0  0.138135
# 601010101002-031_0  0.135359
# 601010101002-041_0  0.138433
# 601010101002-054_0  0.136619
# 601010101002-060_0 -0.077414
# ...                      ...
# 601050504009-051_0  0.182834
# 601050504009-070_0  0.171517
# 601050504009-098_0  0.184575
# 601050504009-143_0  0.171553
# 601050504009-156_0  0.171501
#
# [5233 rows x 10 columns]
