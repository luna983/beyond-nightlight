# %%
import os
import json
import numpy as np
import pandas as pd
from argparse import Namespace
from glob import glob

# %%
SVY_IN_DIR = 'data/GiveDirectly/Survey/household.dta'
SAT_IN_DIR = 'data/GiveDirectly/Pred/infer/'
OUT_DIR = 'data/GiveDirectly/merged.csv'

# set up visualization cfg
cfg = Namespace()
cfg.visual_score_cutoff = 0.9

# %%
df = pd.read_stata(SVY_IN_DIR)
df = df.dropna(subset=['s19_gps_latitude', 's19_gps_longitude'])

# %%
# read satellite predictions
# from json annotations
df_sat = []
for file_name in glob(os.path.join(SAT_IN_DIR, '*.json')):
    with open(file_name, 'r') as f:
        df_sat += json.load(f)
df_sat = pd.DataFrame(df_sat)

# drop low score predictions
df_sat = df_sat.loc[df_sat['score'] > cfg.visual_score_cutoff, :]

# %%
df_sat['category_id'].replace(
    {1: 'thatched', 2: 'metal', 3: 'colored'}, inplace=True)

# %%
df_sat
# Out:
#                                             segmentation  \
# 0      {'size': [800, 800], 'counts': 'co]7h0og0:L4M2...
# 1      {'size': [800, 800], 'counts': '_db96gh04M3M2M...
# 2      {'size': [800, 800], 'counts': 'kT[17eh06K3M4J...
# 4      {'size': [800, 800], 'counts': 'Zed:5ih04L3N3M...
# 5      {'size': [800, 800], 'counts': '\ZY89fh03N3L3N...
# ...                                                  ...
# 36945  {'size': [800, 800], 'counts': 'og_b0^1bg000O1...
# 36946  {'size': [800, 800], 'counts': 'eSe54kh02N2N3N...
# 36947  {'size': [800, 800], 'counts': '`SS63kh05L2N2N...
# 36948  {'size': [800, 800], 'counts': 'Rid::dh04L4M2N...
# 36949  {'size': [800, 800], 'counts': 'ZcZ84kh02N3N1N...
#
#                                                     bbox     score    area  \
# 0      [303.96514892578125, 483.6033935546875, 61.135...  0.999874  2616.0
# 1      [390.64776611328125, 350.5533752441406, 69.738...  0.999759  3197.0
# 2      [55.012939453125, 165.5957794189453, 38.862304...  0.995076  1060.0
# 4      [431.2185974121094, 0.0, 110.86050415039062, 1...  0.999966  6870.0
# 5      [339.1448974609375, 470.09857177734375, 89.540...  0.999945  4315.0
# ...                                                  ...       ...     ...
# 36945  [756.798095703125, 348.59075927734375, 42.9449...  0.999768  2062.0
# 36946  [231.73077392578125, 641.6854248046875, 48.781...  0.999517  1463.0
# 36947  [248.94029235839844, 551.2299194335938, 86.294...  0.999350  4417.0
# 36948  [435.94049072265625, 120.67565155029297, 95.66...  0.999129  4772.0
# 36949  [340.95294189453125, 189.78173828125, 33.89099...  0.994045   650.0
#
#            image_id_str  image_id category_id
# 0      601040506010-082      3490       metal
# 1      601040506010-082      3490       metal
# 2      601040506010-082      3490    thatched
# 4      601010105009-032       216       metal
# 5      601010105009-032       216       metal
# ...                 ...       ...         ...
# 36945  601050103008-097      4078       metal
# 36946  601050103008-097      4078       metal
# 36947  601050103008-097      4078       metal
# 36948  601050103008-097      4078       metal
# 36949  601050103008-097      4078    thatched
#
# [21587 rows x 7 columns]

# %%
# grouping
df_cat = df_sat.groupby(['image_id_str', 'category_id']).agg(
    sat_house=pd.NamedAgg(column='area', aggfunc='count'),
    sat_size_mean=pd.NamedAgg(column='area', aggfunc=np.nanmean),
    sat_size_sum=pd.NamedAgg(column='area', aggfunc=np.nansum)
).reset_index()

# %%
df_all = df_sat.groupby(['image_id_str']).agg(
    sat_house=pd.NamedAgg(column='area', aggfunc='count'),
    sat_size_mean=pd.NamedAgg(column='area', aggfunc=np.nanmean),
    sat_size_sum=pd.NamedAgg(column='area', aggfunc=np.nansum)
).reset_index()

# %%
df_sat = pd.concat([df_cat, df_all.assign(category_id='all')], sort=True)

# %%
# scale areas / distances
df_sat[[col for col in df_sat.columns if col.startswith('sat_size')]] *= (
    (0.298 ** 2) * (640 ** 2) / (800 ** 2) * np.cos(23 / 180 * np.pi))  # in sq meters

# %%
df_sat = df_sat.pivot(
    index='image_id_str', columns='category_id',
    values=['sat_house', 'sat_size_mean', 'sat_size_sum'])

# %%
df_sat_columns = ['_'.join(cols[::-1]) for cols in df_sat.columns]
df_sat.columns = df_sat_columns

# %%
df = pd.merge(df, df_sat, how='left', left_on='s1_hhid_key', right_on='image_id_str')

# %%
cols = [col for col in df_sat_columns if col.endswith(('sat_house', 'sat_size_sum'))]
df[cols] = df[cols].fillna(0)

# %%
df.to_csv(OUT_DIR, index=False)

# %%
df
# Out:
#            s1_hhid_key  s6_q1_haselectricity s6_q1a_electype  \
# 0     601010101002-002                   2.0
# 1     601010101002-031                   2.0
# 2     601010101002-041                   2.0
# 3     601010101002-054                   2.0
# 4     601010101002-060                   1.0               1
# ...                ...                   ...             ...
# 5228  601050504009-051                   2.0
# 5229  601050504009-070                   2.0
# 5230  601050504009-098                   2.0
# 5231  601050504009-143                   2.0
# 5232  601050504009-156                   2.0
#
#       s6_q6_acresowned  s6_q6b_agacresowned  s6_q7_rentedland  \
# 0                2.000                1.500               2.0
# 1                0.500                0.500               2.0
# 2                1.000                0.500               2.0
# 3                0.500                0.500               2.0
# 4                0.500                0.500               2.0
# ...                ...                  ...               ...
# 5228             0.250                0.250               2.0
# 5229             0.250                0.250               2.0
# 5230             0.625                0.625               2.0
# 5231             0.500                0.500               2.0
# 5232             0.750                0.750               2.0
#
#       s6_q7a_acresrented  s6_q7b_monthsrented  s6_q7ci_landrent  \
# 0                    NaN                  NaN               NaN
# 1                    NaN                  NaN               NaN
# 2                    NaN                  NaN               NaN
# 3                    NaN                  NaN               NaN
# 4                    NaN                  NaN               NaN
# ...                  ...                  ...               ...
# 5228                 NaN                  NaN               NaN
# 5229                 NaN                  NaN               NaN
# 5230                 NaN                  NaN               NaN
# 5231                 NaN                  NaN               NaN
# 5232                 NaN                  NaN               NaN
#
#       s6_q8_landrenting  ...  metal_sat_house  thatched_sat_house  \
# 0                   2.0  ...              4.0                 2.0
# 1                   1.0  ...              4.0                 3.0
# 2                   2.0  ...              1.0                 0.0
# 3                   2.0  ...              3.0                 3.0
# 4                   2.0  ...             12.0                 2.0
# ...                 ...  ...              ...                 ...
# 5228                2.0  ...              2.0                 1.0
# 5229                2.0  ...              4.0                 3.0
# 5230                1.0  ...              3.0                 2.0
# 5231                2.0  ...              5.0                 1.0
# 5232                2.0  ...              4.0                 3.0
#
#       all_sat_size_mean  colored_sat_size_mean  metal_sat_size_mean  \
# 0            191.732456             371.499384           153.823555
# 1            156.934517                    NaN           190.628204
# 2            502.552187                    NaN           502.552187
# 3             46.021071                    NaN            50.938821
# 4            297.086653                    NaN           315.542540
# ...                 ...                    ...                  ...
# 5228         121.077793                    NaN           102.880374
# 5229         125.873471                    NaN           158.362010
# 5230         182.793810                    NaN           133.441923
# 5231         132.181345             146.538484           133.229169
# 5232         122.816693                    NaN           154.830647
#
#       thatched_sat_size_mean  all_sat_size_sum  colored_sat_size_sum  \
# 0                 177.666794       1342.127191            371.499384
# 1                 112.009602       1098.541622              0.000000
# 2                        NaN        502.552187              0.000000
# 3                  41.103321        276.126425              0.000000
# 4                 186.351331       4159.213138              0.000000
# ...                      ...               ...                   ...
# 5228              157.472630        363.233378              0.000000
# 5229               82.555419        881.114296              0.000000
# 5230              256.821641        913.969051              0.000000
# 5231              112.585083        925.269412            146.538484
# 5232               80.131421        859.716853              0.000000
#
#       metal_sat_size_sum  thatched_sat_size_sum
# 0             615.294219             355.333589
# 1             762.512817             336.028805
# 2             502.552187               0.000000
# 3             152.816462             123.309963
# 4            3786.510475             372.702663
# ...                  ...                    ...
# 5228          205.760749             157.472630
# 5229          633.448041             247.666256
# 5230          400.325769             513.643282
# 5231          666.145846             112.585083
# 5232          619.322589             240.394264
#
# [5233 rows x 42 columns]
